# %%
import copy

rounds_to_play = 250
smyb_d = "."
smyb_a = "#"

starting_position = [[smyb_d, smyb_d, smyb_d, smyb_a, smyb_d, smyb_a, smyb_d, smyb_d, smyb_d, smyb_d], 
              [smyb_a, smyb_d, smyb_a, smyb_d, smyb_d, smyb_a, smyb_a, smyb_a, smyb_d, smyb_d], 
              [smyb_d, smyb_d, smyb_a, smyb_a, smyb_a, smyb_d, smyb_d, smyb_d, smyb_d, smyb_a], 
              [smyb_a, smyb_d, smyb_d, smyb_d, smyb_d, smyb_d, smyb_d, smyb_d, smyb_d, smyb_d], 
              [smyb_d, smyb_d, smyb_d, smyb_d, smyb_a, smyb_a, smyb_d, smyb_d, smyb_d, smyb_a], 
              [smyb_d, smyb_d, smyb_d, smyb_a, smyb_a, smyb_a, smyb_a, smyb_d, smyb_d, smyb_d], 
              [smyb_d, smyb_d, smyb_d, smyb_d, smyb_d, smyb_a, smyb_d, smyb_d, smyb_d, smyb_a], 
              [smyb_d, smyb_d, smyb_d, smyb_d, smyb_d, smyb_d, smyb_d, smyb_d, smyb_a, smyb_a], 
              [smyb_d, smyb_a, smyb_d, smyb_a, smyb_d, smyb_a, smyb_d, smyb_d, smyb_d, smyb_d], 
              [smyb_d, smyb_d, smyb_d, smyb_d, smyb_d, smyb_d, smyb_d, smyb_d, smyb_a, smyb_a]]


def check_position(list_number, pos_in_list):
    
    '''evaluates whether a position in the game will be alive or dead in the next round'''
    
    n_status = this_round[list_number][pos_in_list]
    n_alive = 0
    new_list_number = 0
    
    if not pos_in_list == 0:
        if this_round[list_number][pos_in_list - 1] == smyb_a:
            n_alive = n_alive + 1
    if not pos_in_list == 9:
        if this_round[list_number][pos_in_list + 1] == smyb_a:
            n_alive = n_alive + 1
    if not pos_in_list == 0:
        if this_round[list_number - 1][pos_in_list - 1] == smyb_a:
            n_alive = n_alive + 1
    if not list_number == 0:
        if this_round[list_number - 1][pos_in_list] == smyb_a:
            n_alive = n_alive + 1 
    if not list_number == 0:
        if not pos_in_list == 9:
            if this_round[list_number - 1][pos_in_list + 1] == smyb_a:
                n_alive = n_alive + 1
    if not pos_in_list == 0:
        if not list_number == 9:
            if this_round[list_number + 1][pos_in_list - 1] == smyb_a:
                n_alive = n_alive + 1
    if not list_number == 9:
        if this_round[list_number + 1][pos_in_list] == smyb_a:
            n_alive = n_alive + 1
    if not list_number == 9:
        if not pos_in_list == 9:
            if this_round[list_number + 1][pos_in_list + 1] == smyb_a:
                n_alive = n_alive + 1
                
    if n_alive <= 1:
        new_list_number = smyb_d
    if n_alive == 2:
        new_list_number = n_status
    if n_alive == 3:
        new_list_number = smyb_a
    if n_alive >= 4:
        new_list_number = smyb_d
        
    next_round[list_number][pos_in_list] = new_list_number

# %%
this_round = starting_position

next_round = copy.deepcopy(this_round)

print("THIS IS THE STARTING POSITION:")
print('\n'.join(map(str, this_round)))

round_count = 1
for game_of_life_round in range(rounds_to_play):
    
    for li in range(0, 10):
        for num in range(0, 10):
            check_position(li, num)
            
    print("PLAYING ROUND {}:".format(round_count))
    print('\n'.join(map(str, next_round)))
    
    this_round = copy.deepcopy(next_round)
    round_count += 1
# Out:
# THIS IS THE STARTING POSITION:
# ['.', '.', '.', '#', '.', '#', '.', '.', '.', '.']
# ['#', '.', '#', '.', '.', '#', '#', '#', '.', '.']
# ['.', '.', '#', '#', '#', '.', '.', '.', '.', '#']
# ['#', '.', '.', '.', '.', '.', '.', '.', '.', '.']
# ['.', '.', '.', '.', '#', '#', '.', '.', '.', '#']
# ['.', '.', '.', '#', '#', '#', '#', '.', '.', '.']
# ['.', '.', '.', '.', '.', '#', '.', '.', '.', '#']
# ['.', '.', '.', '.', '.', '.', '.', '.', '#', '#']
# ['.', '#', '.', '#', '.', '#', '.', '.', '.', '.']
# ['.', '.', '.', '.', '.', '.', '.', '.', '#', '#']
# PLAYING ROUND 1:
# ['.', '.', '.', '.', '#', '#', '.', '.', '.', '.']
# ['.', '#', '#', '.', '.', '#', '#', '.', '.', '.']
# ['.', '.', '#', '#', '#', '#', '#', '.', '.', '.']
# ['.', '.', '.', '.', '.', '#', '.', '.', '.', '.']
# ['.', '.', '.', '#', '.', '.', '#', '.', '.', '.']
# ['.', '.', '.', '#', '.', '.', '#', '.', '.', '.']
# ['.', '.', '.', '.', '.', '#', '#', '.', '#', '#']
# ...
